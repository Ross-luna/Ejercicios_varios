# %% [markdown]
# # Proyecto COVID-19

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Abrir archivo
df = pd.read_csv("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/201024COVID19MEXICO.csv",encoding='latin1')

print(df.head())
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  ...  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0          2020-10-24      0a9217       1  ...            MÃ©xico           97    2
# 1          2020-10-24      1aa972       2  ...            MÃ©xico           97   97
# 2          2020-10-24      00f853       2  ...            MÃ©xico           97   97
# 3          2020-10-24      1315ae       2  ...            MÃ©xico           97   97
# 4          2020-10-24      1426fb       1  ...            MÃ©xico           97   97
#
# [5 rows x 38 columns]

# %%
#SE CONVIERTE A FORMATO FECHA LA FECHA DE INGRESO Y SINTOMAS
df[["FECHA_INGRESO", "FECHA_SINTOMAS","FECHA_ACTUALIZACION"]] = df[["FECHA_INGRESO", "FECHA_SINTOMAS","FECHA_ACTUALIZACION"]].apply(pd.to_datetime)

# %%
#Se borran los columnas con otros formatos(fechas y texto)
df.drop(["FECHA_ACTUALIZACION", "ID_REGISTRO","FECHA_INGRESO","FECHA_SINTOMAS","FECHA_DEF","PAIS_NACIONALIDAD"], axis = 'columns', inplace=True)

# %%
#Guardar los cambios en CSV
df.to_csv('COVID-FECHA.csv')

# %%
sns.scatterplot(df['HIPERTENSION'], df['DIABETES']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.columns
# Out:
# Index(['ORIGEN', 'SECTOR', 'ENTIDAD_UM', 'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES',
#        'MUNICIPIO_RES', 'TIPO_PACIENTE', 'INTUBADO', 'NEUMONIA', 'EDAD',
#        'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA', 'RESULTADO_LAB', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %% [markdown]
# Neurona

# %%
# Crea tu primer MLP en Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy
# Fija las semillas aleatorias para la reproducibilidad
numpy.random.seed(7)

# %%
# carga los datos
df = numpy.loadtxt("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/COVID-FECHA.csv", delimiter=",")
# dividido en variables de entrada (X) y salida (Y)
X = df[:0:32]
Y = df[:32]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0fc301af5f06> in <module>()
#       1 # carga los datos
# ----> 2 df = numpy.loadtxt("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/COVID-FECHA.csv", delimiter=",")
#       3 # dividido en variables de entrada (X) y salida (Y)
#       4 X = df[:0:32]
#       5 Y = df[:32]
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1085
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_2 = LinearRegression()

# %%
lr_2.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ce964a74f770> in <module>()
# ----> 1 lr_2.fit(X, y)
#
# NameError: name 'X' is not defined

# %%
y_pred = lr_2.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-99a6bd649556> in <module>()
# ----> 1 y_pred = lr_2.predict(X)
#
# NameError: name 'X' is not defined

# %%
lr_2.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ce105a09d4ff> in <module>()
# ----> 1 lr_2.score(X, y)
#
# NameError: name 'X' is not defined

# %%
corr = round(df.corr(), 3)

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# # VISUALIZAR ARCHIVO

# %%
#Abrir archivo
df = pd.read_csv("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/201024COVID19MEXICO.csv",encoding='latin1')

print(df.head())
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  ...  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0          2020-10-24      0a9217       1  ...            MÃ©xico           97    2
# 1          2020-10-24      1aa972       2  ...            MÃ©xico           97   97
# 2          2020-10-24      00f853       2  ...            MÃ©xico           97   97
# 3          2020-10-24      1315ae       2  ...            MÃ©xico           97   97
# 4          2020-10-24      1426fb       1  ...            MÃ©xico           97   97
#
# [5 rows x 38 columns]

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  ...  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0          2020-10-24      0a9217       1  ...            MÃ©xico           97    2
# 1          2020-10-24      1aa972       2  ...            MÃ©xico           97   97
# 2          2020-10-24      00f853       2  ...            MÃ©xico           97   97
# 3          2020-10-24      1315ae       2  ...            MÃ©xico           97   97
# 4          2020-10-24      1426fb       1  ...            MÃ©xico           97   97
#
# [5 rows x 38 columns]

# %% [markdown]
# # REMPLAZAR VALORES

# %%
df.ORIGEN = df.ORIGEN.replace ({1:"USMER",2:"FUERA_DE_USMER",99:"NO_ESPECIFICADO"})

# %%
df.SECTOR = df.SECTOR.replace({
     1:"CRUZ_ROJA",
     2:"DIF",3:"ESTATAL",
     4:"IMSS",
     5:"IMSS-BIENESTAR",
     6:"ISSSTE",
     7:"MUNICIPAL",
     8:"PEMEX",
     9:"PRIVADA",
     10:"SEDENA",
     11:"SEMAR",
     12:"SSA",
     13:"UNIVERSITARIO",
     99:"NO ESPECIFICADO"})

# %%
df.ENTIDAD_UM = df.ENTIDAD_UM.replace(
    {
        1:"AGUASCALIENTES",
        2:"BAJA_CALIFORNIA",
        3:"BAJA_CALIFORNIA_SUR",
        4:"CAMPECHE",
        5:"COAHUILA_DE_ZARAGOZA",
        6:"COLIMA",
        7:"CHIAPAS",
        8:"CHIHUAHUA",
        9:"CIUDAD_DE_MÉXICO",
        10:"DURANGO",
        11:"GUANAJUATO",
        12:"GUERRERO",
        13:"HIDALGO",
        14:"JALISCO",
        15:"MÉXICO",
        16:"MICHOACÁN_DE_OCAMPO",
        17:"MORELOS",
        18:"NAYARIT",
        19:"NUEVO_LEÓN",
        20:"OAXACA",
        21:"PUEBLA",
        22:"QUERÉTARO",
        23:"QUINTANA_ROO",
        24:"SAN_LUIS_POTOSÍ",
        25:"SINALOA",
        26:"SONORA",
        27:"TABASCO",
        28:"TAMAULIPAS",
        29:"TLAXCALA",
        30:"VERACRUZ_DE_IGNACIO_DE_LA_LLAVE",
        31:"YUCATÁN",
        32:"ZACATECAS",
        36:"ESTADOS_UNIDOS_MEXICANOS",
        97:"NO_APLICA",
        98:"SE_IGNORA",
        99:"NO_ESPECIFICADO"
 
    }
)

# %%
df.SEXO = df.SEXO.replace({
    1:"MUJER",
    2:"HOMBRE",
    99:"NO ESPECIFICADO"
})

# %%
df.ENTIDAD_NAC = df.ENTIDAD_NAC.replace(
    {
        1:"AGUASCALIENTES",
        2:"BAJA_CALIFORNIA",
        3:"BAJA_CALIFORNIA_SUR",
        4:"CAMPECHE",
        5:"COAHUILA_DE_ZARAGOZA",
        6:"COLIMA",
        7:"CHIAPAS",
        8:"CHIHUAHUA",
        9:"CIUDAD_DE_MÉXICO",
        10:"DURANGO",
        11:"GUANAJUATO",
        12:"GUERRERO",
        13:"HIDALGO",
        14:"JALISCO",
        15:"MÉXICO",
        16:"MICHOACÁN_DE_OCAMPO",
        17:"MORELOS",
        18:"NAYARIT",
        19:"NUEVO_LEÓN",
        20:"OAXACA",
        21:"PUEBLA",
        22:"QUERÉTARO",
        23:"QUINTANA_ROO",
        24:"SAN_LUIS_POTOSÍ",
        25:"SINALOA",
        26:"SONORA",
        27:"TABASCO",
        28:"TAMAULIPAS",
        29:"TLAXCALA",
        30:"VERACRUZ_DE_IGNACIO_DE_LA_LLAVE",
        31:"YUCATÁN",
        32:"ZACATECAS",
        36:"ESTADOS_UNIDOS_MEXICANOS",
        97:"NO_APLICA",
        98:"SE_IGNORA",
        99:"NO_ESPECIFICADO"
 
    }
)

# %%
df.ENTIDAD_RES = df.ENTIDAD_RES.replace(
    {
        1:"AGUASCALIENTES",
        2:"BAJA_CALIFORNIA",
        3:"BAJA_CALIFORNIA_SUR",
        4:"CAMPECHE",
        5:"COAHUILA_DE_ZARAGOZA",
        6:"COLIMA",
        7:"CHIAPAS",
        8:"CHIHUAHUA",
        9:"CIUDAD_DE_MÉXICO",
        10:"DURANGO",
        11:"GUANAJUATO",
        12:"GUERRERO",
        13:"HIDALGO",
        14:"JALISCO",
        15:"MÉXICO",
        16:"MICHOACÁN_DE_OCAMPO",
        17:"MORELOS",
        18:"NAYARIT",
        19:"NUEVO_LEÓN",
        20:"OAXACA",
        21:"PUEBLA",
        22:"QUERÉTARO",
        23:"QUINTANA_ROO",
        24:"SAN_LUIS_POTOSÍ",
        25:"SINALOA",
        26:"SONORA",
        27:"TABASCO",
        28:"TAMAULIPAS",
        29:"TLAXCALA",
        30:"VERACRUZ_DE_IGNACIO_DE_LA_LLAVE",
        31:"YUCATÁN",
        32:"ZACATECAS",
        36:"ESTADOS_UNIDOS_MEXICANOS",
        97:"NO_APLICA",
        98:"SE_IGNORA",
        99:"NO_ESPECIFICADO"
 
    }
)

# %%
df.TIPO_PACIENTE = df.TIPO_PACIENTE.replace({
    1:"AMBULATORIO",
    2:"HOSPITALIZADO",
    99:"NO ESPECIFICADO"
})

# %%
df.INTUBADO = df.INTUBADO.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.NEUMONIA = df.NEUMONIA.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.NACIONALIDAD = df.NACIONALIDAD.replace({
    1:"MEXICANA",
    2:"EXTRANJERA",
    99:"NO_ESPECIFICADO",
})

# %%
df.EMBARAZO = df.EMBARAZO.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.HABLA_LENGUA_INDIG = df.HABLA_LENGUA_INDIG.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.DIABETES = df.DIABETES.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.EPOC = df.EPOC.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.ASMA = df.ASMA.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.INMUSUPR = df.INMUSUPR.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.HIPERTENSION = df.HIPERTENSION.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.OTRA_COM = df.OTRA_COM.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.CARDIOVASCULAR = df.CARDIOVASCULAR.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.OBESIDAD = df.OBESIDAD.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.RENAL_CRONICA = df.RENAL_CRONICA.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.TABAQUISMO = df.TABAQUISMO.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.OTRO_CASO = df.OTRO_CASO.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.RESULTADO_LAB = df.RESULTADO_LAB.replace({
    1:"Positivo SARS-CoV-2",
    2:"No positivo SARS-CoV-2",
    3:"Resultado pendiente",  
    4:"Resultado no adecuado",
    97:"No aplica(caso sin muestra" 
})

# %%
df.MIGRANTE = df.MIGRANTE.replace({
    1:"SI",
    2:"NO",
    97:"NO_APLICA",
    98:"SE_IGNORA",
    99:"NO_ESPECIFICADO"
 
})

# %%
df.PAIS_NACIONALIDAD = df.PAIS_NACIONALIDAD.replace({
    "MÃ©xico":"México"
})

# %%
df.PAIS_NACIONALIDAD = df.PAIS_NACIONALIDAD.replace({
    "Ã©":"é"
})

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ... PAIS_ORIGEN UCI
# 0          2020-10-24      0a9217  ...          97   2
# 1          2020-10-24      1aa972  ...          97  97
# 2          2020-10-24      00f853  ...          97  97
# 3          2020-10-24      1315ae  ...          97  97
# 4          2020-10-24      1426fb  ...          97  97
#
# [5 rows x 38 columns]

# %%
#Guardar los cambios en CSV
df.to_csv('COVID-OCT.csv')

# %% [markdown]
# # ARCHIVO REPLACE

# %%
#Abrir archivo con los replace
df = pd.read_csv("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/COVID-OCT.csv")

print(df.head())
# Out:
#    Unnamed: 0 FECHA_ACTUALIZACION  ... PAIS_ORIGEN UCI
# 0           0          2020-10-24  ...          97   2
# 1           1          2020-10-24  ...          97  97
# 2           2          2020-10-24  ...          97  97
# 3           3          2020-10-24  ...          97  97
# 4           4          2020-10-24  ...          97  97
#
# [5 rows x 39 columns]

# %%
df.head()
# Out:
#    Unnamed: 0 FECHA_ACTUALIZACION  ... PAIS_ORIGEN UCI
# 0           0          2020-10-24  ...          97   2
# 1           1          2020-10-24  ...          97  97
# 2           2          2020-10-24  ...          97  97
# 3           3          2020-10-24  ...          97  97
# 4           4          2020-10-24  ...          97  97
#
# [5 rows x 39 columns]

# %%
#Se crea columna para contar
df['count'] = 1

# %%
agrupado = df.groupby(['RESULTADO_LAB', 'SEXO'])['count'].sum()
agrupado
# Out:
# RESULTADO_LAB               SEXO
# No aplica(caso sin muestra  HOMBRE    100904
#                             MUJER     101925
# No positivo SARS-CoV-2      HOMBRE    494185
#                             MUJER     572461
# Positivo SARS-CoV-2         HOMBRE    442974
#                             MUJER     417466
# Resultado no adecuado       HOMBRE     50253
#                             MUJER      48978
# Resultado pendiente         HOMBRE     27882
#                             MUJER      31561
# Name: count, dtype: int64

# %%
#Se utiliza agrupado para obtener solo positivos en columna RESULTADO
agrupado.loc [["Positivo SARS-CoV-2"],["MUJER","HOMBRE"]]
# Out:
# RESULTADO_LAB        SEXO
# Positivo SARS-CoV-2  MUJER     417466
#                      HOMBRE    442974
# Name: count, dtype: int64

# %%
#Columna RESULTADO se pasa a frecuencia para poder graficar
RESULTADO_frecuencia = df["RESULTADO_LAB"].value_counts()

RESULTADO_frecuencia
# Out:
# No positivo SARS-CoV-2        1066646
# Positivo SARS-CoV-2            860440
# No aplica(caso sin muestra     202829
# Resultado no adecuado           99231
# Resultado pendiente             59443
# Name: RESULTADO_LAB, dtype: int64

# %%
 
plt.pie(RESULTADO_frecuencia, labels= RESULTADO_frecuencia.index, autopct="%0.1f %%");
plt.title("México:Resultado de personas sospechosas de COVID-19"),
# Out:
# (Text(0.5, 1.0, 'México:Resultado de personas sospechosas de COVID-19'),)

# %%
sns.barplot(RESULTADO_frecuencia.index, RESULTADO_frecuencia, palette='Pastel1');

plt.title("Resultado de personas sospechosas de COVID-19")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Resultado de personas sospechosas de COVID-19')

# %%
df.EDAD.max()
# Out:
# 120

# %%
df.EDAD.min()
# Out:
# 0

# %% [markdown]
# #BORRADO DE REGISTROS

# %%
#Se borran los registros que contienen "No positivo SARS" en la columna RESULTADO
df = df.drop(df[df['RESULTADO_LAB']=="No positivo SARS-CoV-2"].index)
#Se borran los resgitros que contienen "Resultado pendiente" en columna RESULTADO
df = df.drop(df[df['RESULTADO_LAB']=="Resultado pendiente"].index)
#Se borran los resgitros que contienen "Resultado pendiente" en columna RESULTADO
df = df.drop(df[df['RESULTADO_LAB']=="Resultado no adecuado"].index)
#Se borran los resgitros que contienen "Resultado pendiente" en columna RESULTADO
df = df.drop(df[df['RESULTADO_LAB']=="No aplica (caso sin muestra"].index)

# %%
df.head()
# Out:
#    Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ... PAIS_ORIGEN UCI count
# 0           0          2020-10-24      0a9217  ...          97   2     1
# 1           1          2020-10-24      1aa972  ...          97  97     1
# 2           2          2020-10-24      00f853  ...          97  97     1
# 3           3          2020-10-24      1315ae  ...          97  97     1
# 4           4          2020-10-24      1426fb  ...          97  97     1
#
# [5 rows x 40 columns]

# %%
#SE GUARDA NUEVO ARCHIVO SOLO CON CASOS POSITIVOS
df.to_csv('COVID-casos_positivosOCT.csv')

# %% [markdown]
# #ARCHIVO CASOS POSITIVOS

# %%
#SE ABRE ARCHIVO DE SOLO CASOS POSITIVOS
df = pd.read_csv("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/COVID-casos_positivosOCT.csv")

print(df.head())
# Out:
#    Unnamed: 0  Unnamed: 0.1 FECHA_ACTUALIZACION  ... PAIS_ORIGEN UCI count
# 0           0             0          2020-10-24  ...          97   2     1
# 1           1             1          2020-10-24  ...          97  97     1
# 2           2             2          2020-10-24  ...          97  97     1
# 3           3             3          2020-10-24  ...          97  97     1
# 4           4             4          2020-10-24  ...          97  97     1
#
# [5 rows x 41 columns]

# %%
#SE CONVIERTE A FORMATO FECHA LA FECHA DE INGRESO Y SINTOMAS
df[["FECHA_INGRESO", "FECHA_SINTOMAS"]] = df[["FECHA_INGRESO", "FECHA_SINTOMAS"]].apply(pd.to_datetime)

# %%
#SE CREA NUEVA COLUMNA CON EL NUMERO DE SEMANA SEGUN LA FECHA DE INGRESO
df["SEMANA_INGRESO"] = df["FECHA_INGRESO"].dt.strftime('%U')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 FECHA_ACTUALIZACION  ... UCI count SEMANA_INGRESO
# 0           0             0          2020-10-24  ...   2     1             12
# 1           1             1          2020-10-24  ...  97     1             14
# 2           2             2          2020-10-24  ...  97     1             14
# 3           3             3          2020-10-24  ...  97     1             14
# 4           4             4          2020-10-24  ...  97     1             13
#
# [5 rows x 42 columns]

# %% [markdown]
# #TABLAS Y GRÁFICOS

# %%
df.groupby(['RESULTADO_LAB', 'EDAD'])['count'].sum()
# Out:
# RESULTADO_LAB               EDAD
# No aplica(caso sin muestra  0        592
#                             1       1129
#                             2        929
#                             3        792
#                             4        754
#                                     ...
# Positivo SARS-CoV-2         114        2
#                             115        1
#                             116        2
#                             118        2
#                             120        1
# Name: count, Length: 231, dtype: int64

# %%
EDAD_frecuencia = df["EDAD"].value_counts()

EDAD_frecuencia
# Out:
# 30     25047
# 31     24139
# 29     23785
# 37     23715
# 35     23703
#        ...
# 117        2
# 116        2
# 112        2
# 119        2
# 115        1
# Name: EDAD, Length: 119, dtype: int64

# %%
edad = sns.barplot(EDAD_frecuencia.index, EDAD_frecuencia, palette='Set1')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['EDAD'].value_counts().head(20).plot(kind='barh',color="#D291BC", figsize=(20,10),),
plt.title("México 2020: Top 20 de edades con mayor contagio de Covid-19", fontsize = (30))
plt.xlabel('Cantidad', fontsize=30, labelpad=10)
plt.ylabel('Edades', fontsize=30, labelpad= 10)
plt.legend(fontsize=20) 
plt.tick_params(labelsize=20)

# %%
plt.figure(figsize=(30,10))
plt.plot(df['FECHA_INGRESO'].value_counts().sort_index())

# %%
plt.figure(figsize=(30,10))
plt.title("Casos Covid-19 por semana", fontsize=(50))
plt.plot(df['SEMANA_INGRESO'].value_counts().sort_index(),color="purple"),
plt.xlabel('Semana', fontsize=30, labelpad=50)
plt.ylabel('Cantidad', fontsize=30, labelpad= 50)
plt.tick_params(labelsize=20)

# %%
df["ENTIDAD_UM"].value_counts().head(20).plot(kind='barh', figsize=(20,20), color="pink")
plt.title("México 2020: Top 20 de entidades con mayor contagio Covid-19", fontsize = (30))
plt.xlabel('Cantidad', fontsize=30, labelpad=50)
plt.ylabel('Entidades', fontsize=30, labelpad= 50)
plt.legend(fontsize=20)
plt.tick_params(labelsize=20)

# %%
df['count'] = 1

# %%
agrupado = df.groupby(['RESULTADO_LAB', 'SEXO',"OBESIDAD","DIABETES","HIPERTENSION"])['count'].sum()
agrupado
# Out:
# RESULTADO_LAB               SEXO    OBESIDAD  DIABETES   HIPERTENSION
# No aplica(caso sin muestra  HOMBRE  NO        NO         NO              73254
#                                                          SE_IGNORA          23
#                                                          SI               5960
#                                               SE_IGNORA  NO                 46
#                                                          SE_IGNORA          43
#                                                                          ...
# Positivo SARS-CoV-2         MUJER   SI        SE_IGNORA  SE_IGNORA          40
#                                                          SI                 30
#                                               SI         NO               6814
#                                                          SE_IGNORA           8
#                                                          SI              12244
# ...

# %%
agrupado.loc[["Positivo SARS-CoV-2"],["MUJER","HOMBRE"],["SI"],["SI"],["SI"]]
# Out:
# RESULTADO_LAB        SEXO    OBESIDAD  DIABETES  HIPERTENSION
# Positivo SARS-CoV-2  MUJER   SI        SI        SI              12244
#                      HOMBRE  SI        SI        SI               9650
# Name: count, dtype: int64

# %%
# %matplotlib inline
import plotnine as p9

# %%
Edades = p9.theme(axis_text_x = p9.element_text(color='black', size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color='black', size=10))

(p9.ggplot(data=df,
           mapping=p9.aes(x='SEXO'))
    + p9.geom_bar(fill = "Blue", color = "gray",)
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
    + p9.labs(title = "México 2020: Covid-19 por sexo")
    + Edades
    )
# Out:
# /usr/local/lib/python3.6/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (-9223363268906431691)>

# %%
Edades = p9.theme(axis_text_x = p9.element_text(color='black', size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color='black', size=10))

(p9.ggplot(data=df,
           mapping=p9.aes(x='EDAD'))
    + p9.geom_bar(fill = "Blue", color = "gray",)
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
    + p9.labs(title = "México 2020: Covid-19 por edades")
    + Edades
    )
# Out:
# <ggplot: (-9223363268907703215)>

# %%
Entidades = p9.theme(axis_text_x = p9.element_text(color='black', size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color='black', size=10))

(p9.ggplot(data=df,
           mapping=p9.aes(x='ENTIDAD_NAC'))
    + p9.geom_bar(fill = "Blue", color = "gray",)
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
    + p9.labs(title = "México 2020: Covid-19 por entidades")
    + Entidades
    )
# Out:
# /usr/local/lib/python3.6/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8767947081743)>

# %%
#SE CREA NUEVA COLUMNA CON EL NUMERO DE DIAS ENTRE SITOMAS E INGRESO AL SISTEMA DE SALUD
df["DIAS_INCUBA"] = (df['FECHA_INGRESO'] - df['FECHA_SINTOMAS']).dt.days

# %%
Entidades = p9.theme(axis_text_x = p9.element_text(color='black', size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color='black', size=10))

(p9.ggplot(data=df,
           mapping=p9.aes(x='DIAS_INCUBA'))
    + p9.geom_bar(fill = "Blue", color = "gray",)
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
    + p9.labs(title = "México 2020: Diferencia de días entre primer sintoma y el ingreso al sistema de salud por Covid-19")
    + Entidades
    )
# Out:
# <ggplot: (8758818778418)>

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 FECHA_ACTUALIZACION  ... UCI count SEMANA_INGRESO
# 0           0             0          2020-10-24  ...   2     1             12
# 1           1             1          2020-10-24  ...  97     1             14
# 2           2             2          2020-10-24  ...  97     1             14
# 3           3             3          2020-10-24  ...  97     1             14
# 4           4             4          2020-10-24  ...  97     1             13
#
# [5 rows x 42 columns]

# %% [markdown]
# #TABLA MUERTES COVID

# %%
import pandas as pd

# %%
#SE ABRE ARCHIVO DE SOLO CASOS POSITIVOS
df = pd.read_csv("/content/drive/My Drive/PROYECTO BEDU/COVID MÉXICO_2020/octubre2020/COVID-casos_positivosOCT.csv")

print(df.head())
# Out:
#    Unnamed: 0  Unnamed: 0.1 FECHA_ACTUALIZACION  ... PAIS_ORIGEN UCI count
# 0           0             0          2020-10-24  ...          97   2     1
# 1           1             1          2020-10-24  ...          97  97     1
# 2           2             2          2020-10-24  ...          97  97     1
# 3           3             3          2020-10-24  ...          97  97     1
# 4           4             4          2020-10-24  ...          97  97     1
#
# [5 rows x 41 columns]

# %%
#Se borran los registros que contienen "9999-99-99" en la columna FECHA_DEF
df = df.drop(df[df['FECHA_DEF']=="9999-99-99"].index)

# %%
df[["FECHA_DEF"]] = df[["FECHA_DEF"]].apply(pd.to_datetime)

# %%
#SE CREA NUEVA COLUMNA CON EL NUMERO DE SEMANA SEGUN LA FECHA DE DEFUNCION 
df["SEMANA_DEF"] = df["FECHA_DEF"].dt.strftime('%U')

# %%
df.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1 FECHA_ACTUALIZACION  ... UCI count SEMANA_DEF
# 0            0             0          2020-10-24  ...   2     1         13
# 9            9             9          2020-10-24  ...   1     1         13
# 10          10            10          2020-10-24  ...   2     1         13
# 13          13            13          2020-10-24  ...  97     1         14
# 16          16            16          2020-10-24  ...   2     1         13
#
# [5 rows x 42 columns]

# %%
# %matplotlib inline
import plotnine as p9

# %%
(p9.ggplot(data=df))
# Out:
# <ggplot: (-9223363268911359151)>

# %%
plt.figure(figsize=(30,10))
plt.title("México 2020: Muertes Covid-19 por semana", fontsize=(50))
plt.plot(df['SEMANA_DEF'].value_counts().sort_index(),color="purple"),
plt.xlabel('Semana', fontsize=30, labelpad=50)
plt.ylabel('Cantidad', fontsize=30, labelpad= 50)
plt.tick_params(labelsize=20)
